# %% [markdown]
# #**1. 변수**
#
# 변수는 프로그래밍에서 데이터를 저장하고 관리하는 데에 사용되는 중요한 개념
# 변수는 이름이 붙는 메모리 공간
# 값을 저장하거나 참조할 때 사용

# %% [markdown]
# ###1-1. 파이썬의 메모리 구조
#
# * 프로그램이 실행되기 위해서는 먼저 프로그램이 메모리에 로드되어야 한다
#
# * 프로그램에서 사용되는 변수들을 저장할 메모리가 필요
#
# * 컴퓨터 운영체제는 프로그램 실행을 위해 메모리를 나누어 관리
#
# * 파이썬의 메모리 영역
#   * 코드 영역: 실행할 프로그램에 코드가 저장되는 영역
#   * 데이터 영역: 프로그램의 전역 변수, 지역변수들이 저장되는 영역
#   * 스택 영역: 함수의 호출과 관계되는 지역변수, 매개변수가 저장되는 영역
#   * 힙 영역: 사용자가 직접 관리할 수 있는 메모리 영역, 메모리 공간이 동적으로 할당되고 해제된다

# %% [markdown]
#  ### 1-2. 변수의 사용
#    변수명 = 값

# %%
name= '김사과'
print(name)

# %%
name= '김사과'
print(name)
age=20
print(age)
# Out:
# 김사과
# 20

# %%
name='반하나'
print(name)
# Out:
# 반하나

# %% [markdown]
# ###1-2. 변수 이름 작성하는 방법
# 파이썬 변수는 대소문자를 구분하며, 예약어 (예: if, while, for 등)는 변수 이름으로 사용할 수 없습니다. 변수 이름은 알파벳으로 시작해야 하며, 숫자나 특수문자는 첫 글자로 올 수 없습니다. 변수 이름은 의미있고 알아보기 쉬운 이름으로 지정하는 것이 좋습니다.

# %%
#변수는 대소문자를 구별한다
num=10 #스칼라(데이터 한 개)를 저장하는 경우 관례적으로 변수의 이름은 소문자로 표현한다
nUm=20 #두 단어를 합쳐 표현하는 경우 앞글자는 소문자, 뒷글자는 대문자가 관례적이다 myScore
nuM=30
print(num)
print(nUm)
print(nuM)
# Out:
# 10
# 20
# 30

# %%
#if = 100 #error: 예약어는 변수 이름으로 사용할 수 없다
#0num=1 #error: 변수 이름은 항상 영문자로 시작해야 한다

# %%
숫자1=200
숫자2=100
print(숫자1)
print(숫자2)
#한글도 변수로 사용은 가능하지만 각 나라의 os마다 유니코드가 달라 깨져 보일 수도 있다 - 자제
# Out:
# 200
# 100

# %% [markdown]
# #**2. 변수의 자료형**
#
# 파이썬은 동적 타이핑(dynamic typing) 언어로, 변수의 타입을 선언할 필요 없이 값을 할당할 때 자동으로 타입을 추론합니다. 이는 프로그래머가 변수의 타입을 직접 명시할 필요 없이 더 유연하게 코드를 작성할 수 있는 장점을 제공합니다. 그렇지만 이로 인해 잘못된 타입의 값이 변수에 할당되는 상황도 발생할 수 있습니다.

# %%
num=10
num = "사과"

# %%
name="김사과"
age=20
weight=50.5
isLover=False

print(name)
print(age)
print(weight)
print(isLover)
# Out:
# 김사과
# 20
# 50.5
# False

# %%
#타입 함수
#type() 파이썬에서 객체의 타입(클래스)를 확인
print(type(name)) #str: 문자열  <class 'str'>
print(type(age))  #int: 정수  <class 'int'>
print(type(weight)) #float: 실수  <class 'float'>
print(type(isLover))  #boolean: 참거짓   <class 'bool'>
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# # **3. 변수의 삭제**
#
# 변수를 삭제하기 위해 del 문을 사용할 수 있습니다. del 문은 지정된 변수를 제거하고 해당 메모리 공간을 해제합니다. 변수가 삭제되면 해당 이름으로 변수에 더 이상 접근할 수 없습니다.

# %%
print(name)
print(age)
print(weight)
print(isLover)
# Out:
# 김사과
# 20
# 50.5
# False

# %%
#isLover 변수 삭제
del isLover
#print(isLover) ##NameError: name 'isLover' is not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-6053910d0aff> in <cell line: 1>()
# ----> 1 print(isLover)
#
# NameError: name 'isLover' is not defined

# %%
name1="김사과"
name2=name1
print(name2)

print(name1)
# Out:
# 김사과
# 김사과

# %%
del name1
print(name2)
# Out:
# 김사과
