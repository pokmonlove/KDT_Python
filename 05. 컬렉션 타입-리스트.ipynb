# %% [markdown]
# #**1. 컬렉션 타입**
# 여러 개의 데이터 항목을 하나의 단위로 관리할 수 있게 해주는 데이터 구조를 의미합니다. 이것은 **여러 개의 데이터를 하나의 변수에 저장**하고, 관리할 수 있게 해줍니다. 파이썬에서는 **리스트, 튜플, 세트, 딕셔너리** 등이 기본적인 컬렉션 타입에 속합니다.

# %% [markdown]
# #**2. 리스트**
#
# 여러 값들을 하나의 변수에 저장하고 관리할 수 있게 해주는 **순차적인** 자료구조입니다.
#
# _인덱스로 구분함_

# %%
list1 = [1, 3, 5, 7, 9]
print(list1)
print(type(list1))
# Out:
# [1, 3, 5, 7, 9]
# <class 'list'>

# %%
list2=list([1, 3, 5, 7, 9]) #컬렉션 함수끼리 자료형을 바꾸기 위해 지원된다
print(list2)
print(type(list2))
# Out:
# [1, 3, 5, 7, 9]
# <class 'list'>

# %%
list3=['반하나', '김사과','오렌지','이메론']
print(list3)
# Out:
# ['반하나', '김사과', '오렌지', '이메론']

# %%
list4=[1, 50.5, '김사과', True]
print(list4)
print(type(list4))
# Out:
# [1, 50.5, '김사과', True]
# <class 'list'>

# %%
print(list4[0])
print(type(list4[0])) #요소마다 데이터 타입이 다를 수 있다
# Out:
# 1
# <class 'int'>

# %%
print(list4[0])
print(list4[1])
print(list4[2])
print(list4[3])
#print(list4[4]) #IndexError: list index out of range
print(type(list4[0]))
print(type(list4[1]))
print(type(list4[2]))
print(type(list4[3]))
# Out:
# 1
# 50.5
# 김사과
# True
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
list1=[1, 3, 5, 7, 9]
print(list1)
print(list1[2])   #5
print(list1[-1])  #9
print(list1[2]+list1[-1]) #5+9
# Out:
# [1, 3, 5, 7, 9]
# 5
# 9
# 14

# %%
#리스트 안에 리스트 저장도 가능하다
list2=[1,2,'파이썬',['김사과','오렌지']]
      #0 1     2       3[0]     3[1]

print(list2)
print(type(list2))
print(list2[1])
print(type(list2[1]))
print(list2[3])
print(type(list2[3]))
print(list2[3][1])
print(type(list2[3][1]))
# Out:
# [1, 2, '파이썬', ['김사과', '오렌지']]
# <class 'list'>
# 2
# <class 'int'>
# ['김사과', '오렌지']
# <class 'list'>
# 오렌지
# <class 'str'>

# %%
list3=[1,2,3,['김사과','오렌지','반하나', ['🍕','🍔','🍟','🌭']]]
print(list3)
print(list3[2])
print(list3[3])
print(list3[-1])
print(list3[-1][-2])
print(list3[-1][-1][2])
# Out:
# [1, 2, 3, ['김사과', '오렌지', '반하나', ['🍕', '🍔', '🍟', '🌭']]]
# 3
# ['김사과', '오렌지', '반하나', ['🍕', '🍔', '🍟', '🌭']]
# ['김사과', '오렌지', '반하나', ['🍕', '🍔', '🍟', '🌭']]
# 반하나
# 🍟

# %%
#슬라이싱

# %%
list1=[1, 3, 5, 7, 9]
print(list1)
print(list1[0:3]) #0부터 3이되기 전까지
# Out:
# [1, 3, 5, 7, 9]
# [1, 3, 5]

# %%
list2=list1
list2[0]=100
print(list2)
print(list1) #같이 바뀐다
# Out:
# [100, 3, 5, 7, 9]
# [100, 3, 5, 7, 9]

# %%
list2=list1
list1[0]=100
print(list2)
print(list1)
# Out:
# [100, 3, 5, 7, 9]
# [100, 3, 5, 7, 9]

# %%
list3=[1,2,3,['김사과','오렌지','반하나', ['🍕','🍔','🍟','🌭']]]
print(list3[2:3])
# Out:
# [3]

# %%
print(list3[3][:2])
# Out:
# ['김사과', '오렌지']

# %%
#슬라이싱을 이용해 요소를 추가한 경우 리스트에 데이터만 포함될 수 있다 (차원이 늘어나지 않는다)
list4=[10,20,30,40,50]
list4[1:2] = ['😀','😁','😂']  #슬라이싱으로 넣으면 차원이 유지된다
print(list4)
print(list4[3])
# Out:
# [10, '😀', '😁', '😂', 30, 40, 50]
# 😂

# %%
#인덱싱을 이용해 요소를 추가한 경우 리스트를 만들고 포함시킨다
list4=[10,20,30,40,50]
list4[1] = ['😀','😁','😂']
print(list4)                #인덱싱으로 넣었더니... 리스트 안에 리스트로 들어갔네? #인덱싱을 하면 차원이 하나씩 낮아진다
print(list4[3])
# Out:
# [10, ['😀', '😁', '😂'], 30, 40, 50]
# 40

# %%
#슬라이싱
list4=[10,20,30,40,50]
print(list4[1:3]) #20, 30
list4[1:3] =[] ##빈 리스트를 슬라이싱을 통해 저장하면 해당 요소가 삭제되는 효과가 있다
print(list4)
# Out:
# [20, 30]
# [10, 40, 50]

# %%
#인덱싱
list4=[10,20,30,40,50]
print(list4[1:3]) #20, 30
list4[1] =[]
print(list4)
# Out:
# [20, 30]
# [10, [], 30, 40, 50]

# %%
#인덱싱으로도 요소롤 삭제할 수 있는 방법
print(list4)
del list4[1]
print(list4)
# Out:
# [10, [], 30, 40, 50]
# [10, 30, 40, 50]

# %%
list5=[10,20,30]
list6=[40,50,60]
print(list5+list6)
print(list6+list5) #리스트끼리 더하면 연결된다
# Out:
# [10, 20, 30, 40, 50, 60]
# [40, 50, 60, 10, 20, 30]

# %%
list5=[10,20,30]
list6=[40,50,60]
print(list5+list6)
list6=list5+[40, 50, 60]
print(list6)
list6 = [10,20,30]
list6+=[40,50,60] #list6=list6+[40,50,60] 과 같은 의미
print(list6)
# Out:
# [10, 20, 30, 40, 50, 60]
# [10, 20, 30, 40, 50, 60]
# [10, 20, 30, 40, 50, 60]

# %%
list6=[10,20,40]
print(list6*3)
# Out:
# [10, 20, 40, 10, 20, 40, 10, 20, 40]

# %% [markdown]
# #3. 리스트의 메서드
#
# 리스트를 다루기 위한 여러 함수와 메소드들이 있습니다.

# %%
print(len("파이썬")) ##
# Out:
# 3

# %%
#len(): 객체의 길이를 반환하는 파이썬의 기본 내장 함수
print(len("파이썬"))
list6=[10,20,30]
print(len(list6))
# Out:
# 3
# 3

# %%
list6=[10,20,30]
print(list6)
#append(): 리스트 요소의 끝에 새로운 요소를 추가해 주는 메소드
list6.append(100)
print(list6)

#list6.append(200,300) #TypeError: list.append() takes exactly one argument (2 given)
#항상 두 개 이상의 데이터를 다룰 땐 리스트나 튜플을 이용해야 한다
list6.append([200,300])
print(list6) #귀찮더라도 하나씩 append 해야 한다
# Out:
# [10, 20, 30]
# [10, 20, 30, 100]
# [10, 20, 30, 100, [200, 300]]

# %%
list6=[10,20,30]
#extend(): 리스트의 요소의 끝에 새로운 여러 요소를 추가
#list6.extend(100) #TypeError: 'int' object is not iterable #순서가 있는 자료 타입으로 넣어 달라는 뜻
list6.extend([100])
print(list6)
list6.extend([100, 200, 300]) #여러 개의 데이터를 넣을 때 쓴다
print(list6)
# Out:
# [10, 20, 30, 100]
# [10, 20, 30, 100, 100, 200, 300]

# %%
list6=[10,20,30]
print(list6)
#pop(): 리스트 마지막 요소를 삭제하고 삭제된 요소를 반환해 주는 함수
temp=list6.pop()
print(temp)
print(list6) #pop한 요소가 없어졌네
# Out:
# [10, 20, 30]
# 30
# [10, 20]

# %%
list6=[10,20,30]
print(list6)
#index(): 리스트에서 특정 값의 인덱스를 반환
print(list6.index(30)) #30에 해당하는 인덱스 값을 찾아 준다
#print(list6.index(100)) #ValueError: 100 is not in list #값이 없으면 에러가 난다
# Out:
# [10, 20, 30]
# 2

# %%
list7=[100,5,70,40,50]
print(list7)
#reverse(): 리스트의 요소들의 순서를 반대로 설정해 준다
list7.reverse()
print(list7)
# Out:
# [100, 5, 70, 40, 50]
# [50, 40, 70, 5, 100]

# %%
#슬라이싱을 사용하여 리스트의 요소들의 순서를 반대로 설정하는 방법
list7=[100,5,70,40,50]
print(list7[:])
print(list7[0:5])
print(list7[::])
print(list7[0:5:1]) #스텝을 생략 스텝의 기본값이 1이기 때문
print(list7[0:5:2]) #스텝을 2로 설정
print(list7[::-1]) #스텝을 -1로 설정: 리버스와 같은 기능
#step이 -1일 경우 start의 기본겂은 -1 stop의 기본값은 0으로 설정
print(list7[1::-1])
print(list7[:0:-1])
# Out:
# [100, 5, 70, 40, 50]
# [100, 5, 70, 40, 50]
# [100, 5, 70, 40, 50]
# [100, 5, 70, 40, 50]
# [100, 70, 50]
# [50, 40, 70, 5, 100]
# [5, 100]
# [50, 40, 70, 5]

# %%
list7=[100,5,70,40,50]
#sort(): 리스트의 요소를 오름차순으로 정렬
list7.sort()
print(list7)

#sort(reverse=True): 리스트의 요소를 내림차순으로 정렬
list7.sort(reverse=True)
print(list7)

#인플레이스 메소드... 값이 바뀐 것을 그대로 저장해 버린다
# Out:
# [5, 40, 50, 70, 100]
# [100, 70, 50, 40, 5]

# %%
list8=['apple', 'Apple.', 'banana', 'orange', 'melon']
print(list8)
list8.sort()
print(list8) #아스키코드 값으로 정렬
# Out:
# ['apple', 'Apple.', 'banana', 'orange', 'melon']
# ['Apple.', 'apple', 'banana', 'melon', 'orange']

# %%
list9=['김사과','오렌지','반하나','이메론']
list9.sort()
print(list9)
# Out:
# ['김사과', '반하나', '오렌지', '이메론']

# %%
##############333

# %%
#sorted(): 모든 요소를 정렬한 후 반환해 주는 함수

# %%
list7=[100,5,70,40,50]
print(list7)

#sorted(list7)
#print(list7) #바뀌지 않음

print(sorted(list7)) #새로운 리스트 반환
print(list7)
# Out:
# [100, 5, 70, 40, 50]
# [5, 40, 50, 70, 100]
# [100, 5, 70, 40, 50]

# %%
list7=[100,5,70,40,50]

#sort 된 것을 어딘가에 저장하고 싶다면 변수 사용해 따로 저장
result = sorted(list7)
print(result)
print(list7)
# Out:
# [5, 40, 50, 70, 100]
# [100, 5, 70, 40, 50]

# %%
list9 = [10,20,30,40,50,60,20,30,20]
#count(): 리스트에서 특정 요소의 갯수 반환
#숫자뿐만 아니라 문자도 가능
print(list9.count(20))
print(list9.count(100))
# Out:
# 3
# 0

# %%
#dot으로 찍어서 실행하는 함수를 메서드라고 생각하면 편하다.
